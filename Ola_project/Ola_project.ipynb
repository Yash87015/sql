# %%
# import necessary library
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
# sql
from sqlalchemy import create_engine
import sqlite3 as sql

# %%
# real OLA_DataSet.xlsx
df = pd.read_excel('OLA_DataSet.xlsx')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103024 entries, 0 to 103023
# Data columns (total 20 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Date                        103024 non-null  datetime64[ns]
#  1   Time                        103024 non-null  object
#  2   Booking_ID                  103024 non-null  object
#  3   Booking_Status              103024 non-null  object
#  4   Customer_ID                 103024 non-null  object
#  5   Vehicle_Type                103024 non-null  object
#  6   Pickup_Location             103024 non-null  object
#  7   Drop_Location               103024 non-null  object
#  8   V_TAT                       63967 non-null   float64
#  9   C_TAT                       63967 non-null   float64
#  10  Canceled_Rides_by_Customer  10499 non-null   object
#  11  Canceled_Rides_by_Driver    18434 non-null   object
#  12  Incomplete_Rides            103024 non-null  object
#  13  Incomplete_Rides_Reason     3926 non-null    object
#  14  Booking_Value               103024 non-null  int64
#  15  Payment_Method              103024 non-null  object
#  16  Ride_Distance               103024 non-null  int64
#  17  Driver_Ratings              63967 non-null   float64
#  18  Customer_Rating             63967 non-null   float64
#  19  Vehicle Images              103024 non-null  object
# dtypes: datetime64[ns](1), float64(4), int64(2), object(13)
# memory usage: 15.7+ MB

# %%
df.head()
# Out:
#                  Date      Time     Booking_ID        Booking_Status  \
# 0 2024-07-26 14:00:00  14:00:00  CNR7153255142    Canceled by Driver
# 1 2024-07-25 22:20:00  22:20:00  CNR2940424040               Success
# 2 2024-07-30 19:59:00  19:59:00  CNR2982357879               Success
# 3 2024-07-22 03:15:00  03:15:00  CNR2395710036  Canceled by Customer
# 4 2024-07-02 09:02:00  09:02:00  CNR1797421769               Success
#
#   Customer_ID Vehicle_Type Pickup_Location Drop_Location  V_TAT  C_TAT  \
# 0   CID713523  Prime Sedan     Tumkur Road      RT Nagar    NaN    NaN
# 1   CID225428         Bike     Magadi Road       Varthur  203.0   30.0
# 2   CID270156    Prime SUV   Sahakar Nagar       Varthur  238.0  130.0
# 3   CID581320        eBike      HSR Layout   Vijayanagar    NaN    NaN
# 4   CID939555         Mini     Rajajinagar   Chamarajpet  252.0   80.0
#
#                      Canceled_Rides_by_Customer      Canceled_Rides_by_Driver  \
# 0                                           NaN  Personal & Car related issue
# 1                                           NaN                           NaN
# 2                                           NaN                           NaN
# 3  Driver is not moving towards pickup location                           NaN
# 4                                           NaN                           NaN
#
#   Incomplete_Rides Incomplete_Rides_Reason  Booking_Value Payment_Method  \
# 0              NaN                     NaN            444            NaN
# 1               No                     NaN            158           Cash
# 2               No                     NaN            386            UPI
# 3              NaN                     NaN            384            NaN
# 4               No                     NaN            822    Credit Card
#
#    Ride_Distance  Driver_Ratings  Customer_Rating  \
# 0              0             NaN              NaN
# 1             13             4.1              4.0
# 2             40             4.2              4.8
# 3              0             NaN              NaN
# 4             45             4.0              3.0
#
#                                       Vehicle Images
# 0  https://cdn-icons-png.flaticon.com/128/14183/1...
# 1  https://cdn-icons-png.flaticon.com/128/9983/99...
# 2  https://cdn-icons-png.flaticon.com/128/9983/99...
# 3  https://cdn-icons-png.flaticon.com/128/6839/68...
# 4  https://cdn-icons-png.flaticon.com/128/3202/32...

# %%
# booking status count
df['Booking_Status'].value_counts()
# Out:
# Booking_Status
# Success                 63967
# Canceled by Driver      18434
# Canceled by Customer    10499
# Driver Not Found        10124
# Name: count, dtype: int64

# %%
# diplicates
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Incomplete_Rides	fill nan withyes
df['Incomplete_Rides'].fillna('Yes', inplace=True)

# %%
# Payment_Method fill nan with Not apllicale
df['Payment_Method'].fillna('Not applicable', inplace=True)

# %%
# incomplate ride reson unique value
df['Incomplete_Rides_Reason'].unique()
# Out:
# array([nan, 'Customer Demand', 'Vehicle Breakdown', 'Other Issue'],
#       dtype=object)

# %%
# Create SQLite database and table
conn = sql.connect('ola_database.db')
df.to_sql('ola_data', conn, if_exists='replace', index=False)
conn.close()

# %%
# Retrieve all successful bookings:
conn = sql.connect('ola_database.db')
query = "SELECT * FROM ola_data WHERE Booking_Status = 'Success'"
successful_bookings = pd.read_sql_query(query, conn)
successful_bookings
# Out:
#                       Date             Time     Booking_ID Booking_Status  \
# 0      2024-07-25 22:20:00  22:20:00.000000  CNR2940424040        Success
# 1      2024-07-30 19:59:00  19:59:00.000000  CNR2982357879        Success
# 2      2024-07-02 09:02:00  09:02:00.000000  CNR1797421769        Success
# 3      2024-07-13 04:42:00  04:42:00.000000  CNR8787177882        Success
# 4      2024-07-23 09:51:00  09:51:00.000000  CNR3612067560        Success
# ...                    ...              ...            ...            ...
# 63962  2024-07-31 09:06:00  09:06:00.000000  CNR9488489435        Success
# 63963  2024-07-31 15:12:00  15:12:00.000000  CNR3151743100        Success
# 63964  2024-07-31 13:59:00  13:59:00.000000  CNR1286151233        Success
# 63965  2024-07-31 14:56:00  14:56:00.000000  CNR2027162035        Success
# 63966  2024-07-31 13:57:00  13:57:00.000000  CNR9770709721        Success
#
#       Customer_ID Vehicle_Type    Pickup_Location  Drop_Location  V_TAT  \
# 0       CID225428         Bike        Magadi Road        Varthur  203.0
# 1       CID270156    Prime SUV      Sahakar Nagar        Varthur  238.0
# 2       CID939555         Mini        Rajajinagar    Chamarajpet  252.0
# 3       CID802429         Mini           Kadugodi    Vijayanagar  231.0
# 4       CID476071         Bike        Tumkur Road     Whitefield  133.0
# ...           ...          ...                ...            ...    ...
# 63962   CID371654   Prime Plus      Richmond Town        Varthur  245.0
# 63963   CID334158         Auto        Vijayanagar  Richmond Town   84.0
# 63964   CID113188    Prime SUV  Bannerghatta Road       JP Nagar   35.0
# 63965   CID118301        eBike        Indiranagar    Magadi Road  210.0
# 63966   CID217959         Auto             Ulsoor         Hennur  175.0
#
#        C_TAT Canceled_Rides_by_Customer Canceled_Rides_by_Driver  \
# 0       30.0                       None                     None
# 1      130.0                       None                     None
# 2       80.0                       None                     None
# 3       90.0                       None                     None
# 4       40.0                       None                     None
# ...      ...                        ...                      ...
# 63962   35.0                       None                     None
# 63963  145.0                       None                     None
# 63964   75.0                       None                     None
# 63965  140.0                       None                     None
# 63966  125.0                       None                     None
#
#       Incomplete_Rides Incomplete_Rides_Reason  Booking_Value Payment_Method  \
# 0                   No                    None            158           Cash
# 1                   No                    None            386            UPI
# 2                   No                    None            822    Credit Card
# 3                   No                    None            173            UPI
# 4                   No                    None            140           Cash
# ...                ...                     ...            ...            ...
# 63962               No                    None            111           Cash
# 63963               No                    None           1097            UPI
# 63964               No                    None           2201           Cash
# 63965               No                    None            267            UPI
# 63966               No                    None            462            UPI
#
#        Ride_Distance  Driver_Ratings  Customer_Rating  \
# 0                 13             4.1              4.0
# 1                 40             4.2              4.8
# 2                 45             4.0              3.0
# 3                 41             3.4              4.6
# 4                 49             3.2              4.5
# ...              ...             ...              ...
# 63962             41             3.6              3.8
# 63963             17             4.3              3.3
# 63964             37             3.6              3.2
# 63965             47             3.4              3.1
# 63966              3             4.8              4.4
#
#                                           Vehicle Images
# 0      https://cdn-icons-png.flaticon.com/128/9983/99...
# 1      https://cdn-icons-png.flaticon.com/128/9983/99...
# 2      https://cdn-icons-png.flaticon.com/128/3202/32...
# 3      https://cdn-icons-png.flaticon.com/128/3202/32...
# 4      https://cdn-icons-png.flaticon.com/128/9983/99...
# ...                                                  ...
# 63962  https://cdn-icons-png.flaticon.com/128/11409/1...
# 63963  https://cdn-icons-png.flaticon.com/128/16526/1...
# 63964  https://cdn-icons-png.flaticon.com/128/9983/99...
# 63965  https://cdn-icons-png.flaticon.com/128/6839/68...
# 63966  https://cdn-icons-png.flaticon.com/128/16526/1...
#
# [63967 rows x 20 columns]

# %%
# Find the average ride distance for each vehicle type
query = "SELECT Vehicle_Type, AVG(Ride_Distance) AS Avg_Ride_Distance FROM ola_data GROUP BY Vehicle_Type"
avg_ride_distance = pd.read_sql_query(query, conn)
avg_ride_distance
# Out:
#   Vehicle_Type  Avg_Ride_Distance
# 0         Auto           6.238089
# 1         Bike          15.533079
# 2         Mini          15.510102
# 3   Prime Plus          15.447474
# 4    Prime SUV          15.274514
# 5  Prime Sedan          15.764939
# 6        eBike          15.580589

# %%
# Get the total number of cancelled rides by customers:
conn = sql.connect('ola_database.db')
query = "SELECT COUNT(*) AS Total_Cancelled_Rides FROM ola_data WHERE Booking_Status = 'Canceled by Customer'"
total_cancelled_rides = pd.read_sql_query(query, conn)
total_cancelled_rides
# Out:
#    Total_Cancelled_Rides
# 0                  10499

# %%
#  List the top 5 customers who booked the highest number of rides:
conn = sql.connect('ola_database.db')
query = "SELECT Customer_ID, COUNT(*) AS Ride_Count FROM ola_data GROUP BY Customer_ID ORDER BY Ride_Count DESC LIMIT 5"
top_customers = pd.read_sql_query(query, conn)
top_customers
# Out:
#   Customer_ID  Ride_Count
# 0   CID954071           5
# 1   CID980727           4
# 2   CID969725           4
# 3   CID966929           4
# 4   CID952434           4

# %%
# Get the number of rides cancelled by drivers due to personal and car-related issues:
conn = sql.connect('ola_database.db')
query = "SELECT COUNT(*) AS Cancelled_Due_To_Personal_Car_Issues FROM ola_data WHERE Booking_Status = 'Canceled by Driver' AND Canceled_Rides_by_Driver = 'Personal & Car related issue'"
cancelled_due_to_personal_car_issues = pd.read_sql_query(query, conn)
cancelled_due_to_personal_car_issues
# Out:
#    Cancelled_Due_To_Personal_Car_Issues
# 0                                  6542

# %%
# . Find the maximum and minimum driver ratings for Prime Sedan bookings:
conn = sql.connect('ola_database.db')
query = "SELECT MAX(Driver_Ratings) AS Max_Rating, MIN(Driver_Ratings) AS Min_Rating FROM ola_data WHERE Vehicle_Type = 'Prime Sedan'"
driver_ratings = pd.read_sql_query(query, conn)
driver_ratings
# Out:
#    Max_Rating  Min_Rating
# 0         5.0         3.0

# %%
# Retrieve all rides where payment was made using UPI:
conn = sql.connect('ola_database.db')
query = "SELECT * FROM ola_data WHERE Payment_Method = 'UPI'"
upi_rides = pd.read_sql_query(query, conn)
upi_rides
# Out:
#                       Date             Time     Booking_ID Booking_Status  \
# 0      2024-07-30 19:59:00  19:59:00.000000  CNR2982357879        Success
# 1      2024-07-13 04:42:00  04:42:00.000000  CNR8787177882        Success
# 2      2024-07-27 13:18:00  13:18:00.000000  CNR4524472111        Success
# 3      2024-07-16 09:54:00  09:54:00.000000  CNR8181602032        Success
# 4      2024-07-02 10:25:00  10:25:00.000000  CNR8090918544        Success
# ...                    ...              ...            ...            ...
# 25876  2024-07-31 19:34:00  19:34:00.000000  CNR4870774895        Success
# 25877  2024-07-31 03:00:00  03:00:00.000000  CNR9738039746        Success
# 25878  2024-07-31 15:12:00  15:12:00.000000  CNR3151743100        Success
# 25879  2024-07-31 14:56:00  14:56:00.000000  CNR2027162035        Success
# 25880  2024-07-31 13:57:00  13:57:00.000000  CNR9770709721        Success
#
#       Customer_ID Vehicle_Type Pickup_Location  Drop_Location  V_TAT  C_TAT  \
# 0       CID270156    Prime SUV   Sahakar Nagar        Varthur  238.0  130.0
# 1       CID802429         Mini        Kadugodi    Vijayanagar  231.0   90.0
# 2       CID540929         Auto        Cox Town      Yelahanka  126.0   35.0
# 3       CID167642         Bike     Indiranagar        MG Road   70.0   95.0
# 4       CID640151         Bike     Magadi Road     HSR Layout  126.0   95.0
# ...           ...          ...             ...            ...    ...    ...
# 25876   CID266336  Prime Sedan    Marathahalli       Cox Town  189.0   30.0
# 25877   CID922711        eBike        Chickpet       RT Nagar   42.0  135.0
# 25878   CID334158         Auto     Vijayanagar  Richmond Town   84.0  145.0
# 25879   CID118301        eBike     Indiranagar    Magadi Road  210.0  140.0
# 25880   CID217959         Auto          Ulsoor         Hennur  175.0  125.0
#
#       Canceled_Rides_by_Customer Canceled_Rides_by_Driver Incomplete_Rides  \
# 0                           None                     None               No
# 1                           None                     None               No
# 2                           None                     None               No
# 3                           None                     None               No
# 4                           None                     None               No
# ...                          ...                      ...              ...
# 25876                       None                     None               No
# 25877                       None                     None               No
# 25878                       None                     None               No
# 25879                       None                     None               No
# 25880                       None                     None               No
#
#       Incomplete_Rides_Reason  Booking_Value Payment_Method  Ride_Distance  \
# 0                        None            386            UPI             40
# 1                        None            173            UPI             41
# 2                        None            330            UPI              8
# 3                        None            378            UPI             18
# 4                        None            343            UPI             23
# ...                       ...            ...            ...            ...
# 25876                    None            280            UPI             38
# 25877                    None            310            UPI              7
# 25878                    None           1097            UPI             17
# 25879                    None            267            UPI             47
# 25880                    None            462            UPI              3
#
#        Driver_Ratings  Customer_Rating  \
# 0                 4.2              4.8
# 1                 3.4              4.6
# 2                 3.0              4.8
# 3                 4.8              4.1
# 4                 3.7              3.6
# ...               ...              ...
# 25876             3.4              4.1
# 25877             3.8              3.3
# 25878             4.3              3.3
# 25879             3.4              3.1
# 25880             4.8              4.4
#
#                                           Vehicle Images
# 0      https://cdn-icons-png.flaticon.com/128/9983/99...
# 1      https://cdn-icons-png.flaticon.com/128/3202/32...
# 2      https://cdn-icons-png.flaticon.com/128/16526/1...
# 3      https://cdn-icons-png.flaticon.com/128/9983/99...
# 4      https://cdn-icons-png.flaticon.com/128/9983/99...
# ...                                                  ...
# 25876  https://cdn-icons-png.flaticon.com/128/14183/1...
# 25877  https://cdn-icons-png.flaticon.com/128/6839/68...
# 25878  https://cdn-icons-png.flaticon.com/128/16526/1...
# 25879  https://cdn-icons-png.flaticon.com/128/6839/68...
# 25880  https://cdn-icons-png.flaticon.com/128/16526/1...
#
# [25881 rows x 20 columns]

# %%
# Find the average customer rating per vehicle type:
conn = sql.connect('ola_database.db')
query = "SELECT Vehicle_Type, AVG(Customer_Rating) AS Avg_Customer_Rating FROM ola_data GROUP BY Vehicle_Type"
avg_customer_rating = pd.read_sql_query(query, conn)
avg_customer_rating
# Out:
#   Vehicle_Type  Avg_Customer_Rating
# 0         Auto             3.998811
# 1         Bike             3.993376
# 2         Mini             3.997731
# 3   Prime Plus             4.009499
# 4    Prime SUV             3.999378
# 5  Prime Sedan             4.001589
# 6        eBike             3.987854

# %%
# Calculate the total booking value of rides completed successfully:
conn = sql.connect('ola_database.db')
query = "SELECT SUM(Booking_Value) AS Total_Booking_Value FROM ola_data WHERE Booking_Status = 'Success'"
total_booking_value = pd.read_sql_query(query, conn)
total_booking_value
# Out:
#    Total_Booking_Value
# 0             35080467

# %%
# List all incomplete rides along with the reason
conn = sql.connect('ola_database.db')
query = "SELECT Booking_ID, Incomplete_Rides_Reason FROM ola_data WHERE Incomplete_Rides = 'Yes'"
incomplete_rides = pd.read_sql_query(query, conn)
incomplete_rides
# Out:
#           Booking_ID Incomplete_Rides_Reason
# 0      CNR7153255142                    None
# 1      CNR2395710036                    None
# 2      CNR5374902489                    None
# 3      CNR5030602354                    None
# 4      CNR6328453219                    None
# ...              ...                     ...
# 42978  CNR2746062760                    None
# 42979  CNR5427755403             Other Issue
# 42980  CNR8606968614                    None
# 42981  CNR1504131542                    None
# 42982  CNR3395373353                    None
#
# [42983 rows x 2 columns]

# %%
# %%writefile Ola.py
import streamlit as st
import pandas as pd
import sqlite3 as sql
import matplotlib.pyplot as plt
import seaborn as sns
import os # Import the os module

# Function to connect to the database and run queries
def run_query(query):
    conn = sql.connect('ola_database.db')
    df = pd.read_sql_query(query, conn)
    conn.close()
    return df

# Load the data (assuming the database is already created and populated)
try:
    # Check if the database file exists
    db_file = 'ola_database.db'
    if not os.path.exists(db_file):
        st.error(f"Database file '{db_file}' not found. Please ensure the database is created and in the same directory as the Streamlit app.")
    else:
        conn = sql.connect(db_file)
        cursor = conn.cursor()
        cursor.execute("SELECT name FROM sqlite_master WHERE type='table' AND name='ola_data';")
        table_exists = cursor.fetchone() is not None
        conn.close()

        if not table_exists:
            st.error("Database table 'ola_data' not found within the database file. Please run the notebook cells to create and populate the database.")
        else:
            st.title('OLA Data Analysis Dashboard')

            # 1. Overall
            with st.expander("1. Overall Analysis"):
                st.subheader('Ride Volume Over Time (Daily)')
                ride_volume_query = "SELECT DATE(Date) as Ride_Date, COUNT(*) as Ride_Count FROM ola_data GROUP BY Ride_Date ORDER BY Ride_Date"
                ride_volume_df = run_query(ride_volume_query)
                st.line_chart(ride_volume_df.set_index('Ride_Date'))

                st.subheader('Booking Status Breakdown')
                booking_status_query = "SELECT Booking_Status, COUNT(*) as Count FROM ola_data GROUP BY Booking_Status"
                booking_status_df = run_query(booking_status_query)
                fig, ax = plt.subplots()
                ax.pie(booking_status_df['Count'], labels=booking_status_df['Booking_Status'], autopct='%1.1f%%', startangle=90)
                ax.axis('equal') # Equal aspect ratio ensures that pie is drawn as a circle.
                st.pyplot(fig)


            # 2. Vehicle Type
            with st.expander("2. Vehicle Type Analysis"):
                st.subheader('Average Ride Distance by Vehicle Type')
                avg_ride_distance_query = "SELECT Vehicle_Type, AVG(Ride_Distance) AS Avg_Ride_Distance FROM ola_data GROUP BY Vehicle_Type"
                avg_ride_distance_df = run_query(avg_ride_distance_query)
                st.bar_chart(avg_ride_distance_df.set_index('Vehicle_Type'))

            # 3. Revenue
            with st.expander("3. Revenue Analysis"):
                st.subheader('Total Booking Value of Successful Rides')
                total_booking_value_query = "SELECT SUM(Booking_Value) AS Total_Booking_Value FROM ola_data WHERE Booking_Status = 'Success'"
                total_booking_value_df = run_query(total_booking_value_query)
                st.write(f"Total Booking Value for Successful Rides: ₹{total_booking_value_df['Total_Booking_Value'].iloc[0]:,.2f}")

                st.subheader('Revenue by Payment Method (for Successful Rides)')
                revenue_by_payment_query = "SELECT Payment_Method, SUM(Booking_Value) AS Total_Revenue FROM ola_data WHERE Booking_Status = 'Success' GROUP BY Payment_Method"
                revenue_by_payment_df = run_query(revenue_by_payment_query)
                st.bar_chart(revenue_by_payment_df.set_index('Payment_Method'))

                st.subheader('Top 5 Customers by Ride Count')
                top_customers_query = "SELECT Customer_ID, COUNT(*) AS Ride_Count FROM ola_data GROUP BY Customer_ID ORDER BY Ride_Count DESC LIMIT 5"
                top_customers_df = run_query(top_customers_query)
                st.dataframe(top_customers_df)


            # 4. Cancellation
            with st.expander("4. Cancellation Analysis"):
                st.subheader('Total Cancelled Rides by Customer')
                total_cancelled_customer_query = "SELECT COUNT(*) AS Total_Cancelled_Rides FROM ola_data WHERE Booking_Status = 'Canceled by Customer'"
                total_cancelled_customer_df = run_query(total_cancelled_customer_query)
                st.write(f"Total Rides Cancelled by Customer: {total_cancelled_customer_df['Total_Cancelled_Rides'].iloc[0]}")

                st.subheader('Cancellation Reasons by Customer')
                cancelled_reasons_customer_query = "SELECT Canceled_Rides_by_Customer, COUNT(*) as Count FROM ola_data WHERE Booking_Status = 'Canceled by Customer' GROUP BY Canceled_Rides_by_Customer"
                cancelled_reasons_customer_df = run_query(cancelled_reasons_customer_query)
                st.dataframe(cancelled_reasons_customer_df)


                st.subheader('Total Cancelled Rides by Driver')
                total_cancelled_driver_query = "SELECT COUNT(*) AS Total_Cancelled_Rides FROM ola_data WHERE Booking_Status = 'Canceled by Driver'"
                total_cancelled_driver_df = run_query(total_cancelled_driver_query)
                st.write(f"Total Rides Cancelled by Driver: {total_cancelled_driver_df['Total_Cancelled_Rides'].iloc[0]}")


                st.subheader('Cancellation Reasons by Driver')
                cancelled_reasons_driver_query = "SELECT Canceled_Rides_by_Driver, COUNT(*) as Count FROM ola_data WHERE Booking_Status = 'Canceled by Driver' GROUP BY Canceled_Rides_by_Driver"
                cancelled_reasons_driver_df = run_query(cancelled_reasons_driver_query)
                st.dataframe(cancelled_reasons_driver_df)


            # 5. Ratings
            with st.expander("5. Ratings Analysis"):
                st.subheader('Average Driver Rating by Vehicle Type')
                avg_driver_rating_query = "SELECT Vehicle_Type, AVG(Driver_Ratings) AS Avg_Driver_Rating FROM ola_data GROUP BY Vehicle_Type"
                avg_driver_rating_df = run_query(avg_driver_rating_query)
                st.bar_chart(avg_driver_rating_df.set_index('Vehicle_Type'))


                st.subheader('Average Customer Rating by Vehicle Type')
                avg_customer_rating_query = "SELECT Vehicle_Type, AVG(Customer_Rating) AS Avg_Customer_Rating FROM ola_data GROUP BY Vehicle_Type"
                avg_customer_rating_df = run_query(avg_customer_rating_query)
                st.bar_chart(avg_customer_rating_df.set_index('Vehicle_Type'))


except Exception as e:
    st.error(f"An error occurred: {e}")
# Out:
# Writing Ola.py

# %%
# %%writefile requirements.txt
# pandas
# numpy
# matplotlib
# seaborn
# sqlalchemy
# streamlit
# Out:
# Writing requirements.txt
